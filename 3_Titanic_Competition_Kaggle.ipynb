# %% [markdown]
# <a href="https://colab.research.google.com/github/imbuoyp/Python-Data/blob/main/3_Titanic_Competition_Kaggle.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # 2. Read Dataset

# %%
from google.colab import files
uploaded = files.upload()

# %%
train_df = pd.read_csv('../Titanic_Disaster/DataSet/train.csv', index_col='PassengerId')
print(train_df.shape)
train_df.head()
# Out:
# (891, 11)
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S

# %%
train_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 1 to 891
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Survived  891 non-null    int64
#  1   Pclass    891 non-null    int64
#  2   Name      891 non-null    object
#  3   Sex       891 non-null    object
#  4   Age       714 non-null    float64
#  5   SibSp     891 non-null    int64
#  6   Parch     891 non-null    int64
#  7   Ticket    891 non-null    object
#  8   Fare      891 non-null    float64
#  9   Cabin     204 non-null    object
#  10  Embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
train_df.describe()
# Out:
#          Survived      Pclass         Age       SibSp       Parch        Fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
test_df = pd.read_csv('../Titanic_Disaster/DataSet/test.csv', index_col='PassengerId')
print(test_df.shape)
test_df.head()
# Out:
# (418, 10)
#              Pclass                                          Name     Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James    male
# 893               3              Wilkes, Mrs. James (Ellen Needs)  female
# 894               2                     Myles, Mr. Thomas Francis    male
# 895               3                              Wirz, Mr. Albert    male
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#               Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# PassengerId
# 892          34.5      0      0   330911   7.8292   NaN        Q
# 893          47.0      1      0   363272   7.0000   NaN        S
# 894          62.0      0      0   240276   9.6875   NaN        Q
# 895          27.0      0      0   315154   8.6625   NaN        S
# 896          22.0      1      1  3101298  12.2875   NaN        S

# %%
test_df.tail()
# Out:
#              Pclass                          Name     Sex   Age  SibSp  Parch  \
# PassengerId
# 1305              3            Spector, Mr. Woolf    male   NaN      0      0
# 1306              1  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 1307              3  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 1308              3           Ware, Mr. Frederick    male   NaN      0      0
# 1309              3      Peter, Master. Michael J    male   NaN      1      1
#
#                          Ticket      Fare Cabin Embarked
# PassengerId
# 1305                  A.5. 3236    8.0500   NaN        S
# 1306                   PC 17758  108.9000  C105        C
# 1307         SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308                     359309    8.0500   NaN        S
# 1309                       2668   22.3583   NaN        C

# %% [markdown]
# # 2. Preprocessing(전처리)

# %%
train_df.loc[train_df['Sex'] == 'female', 'Sex'] = 0
train_df.loc[train_df['Sex'] == 'male', 'Sex'] = 1
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   1  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.0
# 3                                       Heikkinen, Miss. Laina   0  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.0
# 5                                     Allen, Mr. William Henry   1  35.0
# ...                                                        ...  ..   ...
# 887                                      Montvila, Rev. Juozas   1  27.0
# 888                               Graham, Miss. Margaret Edith   0  19.0
# 889                   Johnston, Miss. Catherine Helen "Carrie"   0   NaN
# 890                                      Behr, Mr. Karl Howell   1  26.0
# 891                                        Dooley, Mr. Patrick   1  32.0
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
test_df.loc[test_df['Sex'] == 'female', 'Sex'] = 0
test_df.loc[test_df['Sex'] == 'male', 'Sex'] = 1
test_df
# Out:
#              Pclass                                          Name Sex   Age  \
# PassengerId
# 892               3                              Kelly, Mr. James   1  34.5
# 893               3              Wilkes, Mrs. James (Ellen Needs)   0  47.0
# 894               2                     Myles, Mr. Thomas Francis   1  62.0
# 895               3                              Wirz, Mr. Albert   1  27.0
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   0  22.0
# ...             ...                                           ...  ..   ...
# 1305              3                            Spector, Mr. Woolf   1   NaN
# 1306              1                  Oliva y Ocana, Dona. Fermina   0  39.0
# 1307              3                  Saether, Mr. Simon Sivertsen   1  38.5
# 1308              3                           Ware, Mr. Frederick   1   NaN
# 1309              3                      Peter, Master. Michael J   1   NaN
#
#              SibSp  Parch              Ticket      Fare Cabin Embarked
# PassengerId
# 892              0      0              330911    7.8292   NaN        Q
# 893              1      0              363272    7.0000   NaN        S
# 894              0      0              240276    9.6875   NaN        Q
# 895              0      0              315154    8.6625   NaN        S
# 896              1      1             3101298   12.2875   NaN        S
# ...            ...    ...                 ...       ...   ...      ...
# 1305             0      0           A.5. 3236    8.0500   NaN        S
# 1306             0      0            PC 17758  108.9000  C105        C
# 1307             0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 1308             0      0              359309    8.0500   NaN        S
# 1309             1      1                2668   22.3583   NaN        C
#
# [418 rows x 10 columns]

# %%
train_df[train_df['Fare'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
test_df[test_df['Fare'].isnull()]
# Out:
#              Pclass                Name Sex   Age  SibSp  Parch Ticket  Fare  \
# PassengerId
# 1044              3  Storey, Mr. Thomas   1  60.5      0      0   3701   NaN
#
#             Cabin Embarked
# PassengerId
# 1044          NaN        S

# %%
mean_third_fare = train_df[train_df['Pclass'] == 3]['Fare'].mean()
print(mean_third_fare)
# Out:
# 13.675550101832997

# %%
test_df.loc[test_df['Fare'].isnull(), 'Fare'] = mean_third_fare

# %%
test_df[test_df['Fare'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
mean_age = train_df[train_df['Age'].notnull()].Age.mean()
mean_age
# Out:
# 29.69911764705882

# %%
train_df.loc[train_df['Age'].isnull(), 'Age'] = mean_age
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex        Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   1  22.000000
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.000000
# 3                                       Heikkinen, Miss. Laina   0  26.000000
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.000000
# 5                                     Allen, Mr. William Henry   1  35.000000
# ...                                                        ...  ..        ...
# 887                                      Montvila, Rev. Juozas   1  27.000000
# 888                               Graham, Miss. Margaret Edith   0  19.000000
# 889                   Johnston, Miss. Catherine Helen "Carrie"   0  29.699118
# 890                                      Behr, Mr. Karl Howell   1  26.000000
# 891                                        Dooley, Mr. Patrick   1  32.000000
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
# [891 rows x 11 columns]

# %%
train_df[train_df.Age.isnull()]
# Out:
# Empty DataFrame
# Columns: [Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
test_df.loc[test_df.Age.isnull(), 'Age'] = mean_age

# %% [markdown]
# ## One hot encoding

# %%
'''
C == [1, 0, 0]
S == [0, 1, 0]
Q == [0, 0, 1]

C == [True, False, False]
S == [False, True, False]
Q == [False, False, True]
'''
# Out:
# '\nC == [1, 0, 0]\nS == [0, 1, 0]\nQ == [0, 0, 1]\n\nC == [True, False, False]\nS == [False, True, False]\nQ == [False, False, True]\n'

# %%
train_df['Embarked_C'] = train_df['Embarked'] == 'C'
train_df['Embarked_S'] = train_df['Embarked'] == 'S'
train_df['Embarked_Q'] = train_df['Embarked'] == 'Q'
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex        Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   1  22.000000
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.000000
# 3                                       Heikkinen, Miss. Laina   0  26.000000
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.000000
# 5                                     Allen, Mr. William Henry   1  35.000000
# ...                                                        ...  ..        ...
# 887                                      Montvila, Rev. Juozas   1  27.000000
# 888                               Graham, Miss. Margaret Edith   0  19.000000
# 889                   Johnston, Miss. Catherine Helen "Carrie"   0  29.699118
# 890                                      Behr, Mr. Karl Howell   1  26.000000
# 891                                        Dooley, Mr. Patrick   1  32.000000
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
#              Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 1                 False        True       False
# 2                  True       False       False
# 3                 False        True       False
# 4                 False        True       False
# 5                 False        True       False
# ...                 ...         ...         ...
# 887               False        True       False
# 888               False        True       False
# 889               False        True       False
# 890                True       False       False
# 891               False       False        True
#
# [891 rows x 14 columns]

# %%
test_df['Embarked_C'] = test_df['Embarked'] == 'C'
test_df['Embarked_S'] = test_df['Embarked'] == 'S'
test_df['Embarked_Q'] = test_df['Embarked'] == 'Q'
test_df
# Out:
#              Pclass                                          Name Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James   1
# 893               3              Wilkes, Mrs. James (Ellen Needs)   0
# 894               2                     Myles, Mr. Thomas Francis   1
# 895               3                              Wirz, Mr. Albert   1
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   0
# ...             ...                                           ...  ..
# 1305              3                            Spector, Mr. Woolf   1
# 1306              1                  Oliva y Ocana, Dona. Fermina   0
# 1307              3                  Saether, Mr. Simon Sivertsen   1
# 1308              3                           Ware, Mr. Frederick   1
# 1309              3                      Peter, Master. Michael J   1
#
#                    Age  SibSp  Parch              Ticket      Fare Cabin  \
# PassengerId
# 892          34.500000      0      0              330911    7.8292   NaN
# 893          47.000000      1      0              363272    7.0000   NaN
# 894          62.000000      0      0              240276    9.6875   NaN
# 895          27.000000      0      0              315154    8.6625   NaN
# 896          22.000000      1      1             3101298   12.2875   NaN
# ...                ...    ...    ...                 ...       ...   ...
# 1305         29.699118      0      0           A.5. 3236    8.0500   NaN
# 1306         39.000000      0      0            PC 17758  108.9000  C105
# 1307         38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 1308         29.699118      0      0              359309    8.0500   NaN
# 1309         29.699118      1      1                2668   22.3583   NaN
#
#             Embarked  Embarked_C  Embarked_S  Embarked_Q
# PassengerId
# 892                Q       False       False        True
# 893                S       False        True       False
# 894                Q       False       False        True
# 895                S       False        True       False
# 896                S       False        True       False
# ...              ...         ...         ...         ...
# 1305               S       False        True       False
# 1306               C        True       False       False
# 1307               S       False        True       False
# 1308               S       False        True       False
# 1309               C        True       False       False
#
# [418 rows x 13 columns]

# %%
train_df['Pclass_1'] = train_df['Pclass'] == 1
train_df['Pclass_2'] = train_df['Pclass'] == 2
train_df['Pclass_3'] = train_df['Pclass'] == 3
train_df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name Sex        Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris   1  22.000000
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...   0  38.000000
# 3                                       Heikkinen, Miss. Laina   0  26.000000
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)   0  35.000000
# 5                                     Allen, Mr. William Henry   1  35.000000
# ...                                                        ...  ..        ...
# 887                                      Montvila, Rev. Juozas   1  27.000000
# 888                               Graham, Miss. Margaret Edith   0  19.000000
# 889                   Johnston, Miss. Catherine Helen "Carrie"   0  29.699118
# 890                                      Behr, Mr. Karl Howell   1  26.000000
# 891                                        Dooley, Mr. Patrick   1  32.000000
#
#              SibSp  Parch            Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0         A/5 21171   7.2500   NaN        S
# 2                1      0          PC 17599  71.2833   C85        C
# 3                0      0  STON/O2. 3101282   7.9250   NaN        S
# 4                1      0            113803  53.1000  C123        S
# 5                0      0            373450   8.0500   NaN        S
# ...            ...    ...               ...      ...   ...      ...
# 887              0      0            211536  13.0000   NaN        S
# 888              0      0            112053  30.0000   B42        S
# 889              1      2        W./C. 6607  23.4500   NaN        S
# 890              0      0            111369  30.0000  C148        C
# 891              0      0            370376   7.7500   NaN        Q
#
#              Embarked_C  Embarked_S  Embarked_Q  Pclass_1  Pclass_2  Pclass_3
# PassengerId
# 1                 False        True       False     False     False      True
# 2                  True       False       False      True     False     False
# 3                 False        True       False     False     False      True
# 4                 False        True       False      True     False     False
# 5                 False        True       False     False     False      True
# ...                 ...         ...         ...       ...       ...       ...
# 887               False        True       False     False      True     False
# 888               False        True       False      True     False     False
# 889               False        True       False     False     False      True
# 890                True       False       False      True     False     False
# 891               False       False        True     False     False      True
#
# [891 rows x 17 columns]

# %%
train_df['Pclass'].value_counts()
# Out:
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64

# %%
test_df['Pclass_1'] = test_df['Pclass'] == 1
test_df['Pclass_2'] = test_df['Pclass'] == 2
test_df['Pclass_3'] = test_df['Pclass'] == 3
test_df
# Out:
#              Pclass                                          Name Sex  \
# PassengerId
# 892               3                              Kelly, Mr. James   1
# 893               3              Wilkes, Mrs. James (Ellen Needs)   0
# 894               2                     Myles, Mr. Thomas Francis   1
# 895               3                              Wirz, Mr. Albert   1
# 896               3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)   0
# ...             ...                                           ...  ..
# 1305              3                            Spector, Mr. Woolf   1
# 1306              1                  Oliva y Ocana, Dona. Fermina   0
# 1307              3                  Saether, Mr. Simon Sivertsen   1
# 1308              3                           Ware, Mr. Frederick   1
# 1309              3                      Peter, Master. Michael J   1
#
#                    Age  SibSp  Parch              Ticket      Fare Cabin  \
# PassengerId
# 892          34.500000      0      0              330911    7.8292   NaN
# 893          47.000000      1      0              363272    7.0000   NaN
# 894          62.000000      0      0              240276    9.6875   NaN
# 895          27.000000      0      0              315154    8.6625   NaN
# 896          22.000000      1      1             3101298   12.2875   NaN
# ...                ...    ...    ...                 ...       ...   ...
# 1305         29.699118      0      0           A.5. 3236    8.0500   NaN
# 1306         39.000000      0      0            PC 17758  108.9000  C105
# 1307         38.500000      0      0  SOTON/O.Q. 3101262    7.2500   NaN
# 1308         29.699118      0      0              359309    8.0500   NaN
# 1309         29.699118      1      1                2668   22.3583   NaN
#
#             Embarked  Embarked_C  Embarked_S  Embarked_Q  Pclass_1  Pclass_2  \
# PassengerId
# 892                Q       False       False        True     False     False
# 893                S       False        True       False     False     False
# 894                Q       False       False        True     False      True
# 895                S       False        True       False     False     False
# 896                S       False        True       False     False     False
# ...              ...         ...         ...         ...       ...       ...
# 1305               S       False        True       False     False     False
# 1306               C        True       False       False      True     False
# 1307               S       False        True       False     False     False
# 1308               S       False        True       False     False     False
# 1309               C        True       False       False     False     False
#
#              Pclass_3
# PassengerId
# 892              True
# 893              True
# 894             False
# 895              True
# 896              True
# ...               ...
# 1305             True
# 1306            False
# 1307             True
# 1308             True
# 1309             True
#
# [418 rows x 16 columns]

# %% [markdown]
# # Train

# %%
feature_names = ['Sex', 'Age', 'SibSp', 'Parch', 
       'Fare', 'Embarked_C', 'Embarked_S', 'Embarked_Q',
       'Pclass_1', 'Pclass_2', 'Pclass_3']

# %%
# train_df.columns
feature_names
# Out:
# ['Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Fare',
#  'Embarked_C',
#  'Embarked_S',
#  'Embarked_Q',
#  'Pclass_1',
#  'Pclass_2',
#  'Pclass_3']

# %%
x_train = train_df[feature_names]
print(x_train.shape)
x_train.head()
# Out:
# (891, 11)
#             Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_S  \
# PassengerId
# 1             1  22.0      1      0   7.2500       False        True
# 2             0  38.0      1      0  71.2833        True       False
# 3             0  26.0      0      0   7.9250       False        True
# 4             0  35.0      1      0  53.1000       False        True
# 5             1  35.0      0      0   8.0500       False        True
#
#              Embarked_Q  Pclass_1  Pclass_2  Pclass_3
# PassengerId
# 1                 False     False     False      True
# 2                 False      True     False     False
# 3                 False     False     False      True
# 4                 False      True     False     False
# 5                 False     False     False      True

# %%
x_test = test_df[feature_names]
print(x_test.shape)
x_test.head()
# Out:
# (418, 11)
#             Sex   Age  SibSp  Parch     Fare  Embarked_C  Embarked_S  \
# PassengerId
# 892           1  34.5      0      0   7.8292       False       False
# 893           0  47.0      1      0   7.0000       False        True
# 894           1  62.0      0      0   9.6875       False       False
# 895           1  27.0      0      0   8.6625       False        True
# 896           0  22.0      1      1  12.2875       False        True
#
#              Embarked_Q  Pclass_1  Pclass_2  Pclass_3
# PassengerId
# 892                True     False     False      True
# 893               False     False     False      True
# 894                True     False      True     False
# 895               False     False     False      True
# 896               False     False     False      True

# %%
y_train = train_df['Survived']
y_train
# Out:
# PassengerId
# 1      0
# 2      1
# 3      1
# 4      1
# 5      0
#       ..
# 887    0
# 888    1
# 889    0
# 890    1
# 891    0
# Name: Survived, Length: 891, dtype: int64

# %%
from sklearn.tree import DecisionTreeClassifier #tree라는 클래스로
from sklearn.ensemble import RandomForestClassifier

# %%
model = DecisionTreeClassifier(max_depth=5)
model
# Out:
# DecisionTreeClassifier(max_depth=5)

# %%
model = RandomForestClassifier(max_depth=100,
                      max_features=0.8,
                      n_estimators=500,
                      random_state=42)

model 
 #hyperparamate tuning보면 캐글에 안올려도 for 루프 돌려서 accuracy찾는것.
# Out:
# RandomForestClassifier(max_depth=100, max_features=0.8, n_estimators=500,
#                        random_state=42)

# %%
# help(DecisionTreeClassifier)

# %%
model.fit(x_train, y_train)
# Out:
# RandomForestClassifier(max_depth=100, max_features=0.8, n_estimators=500,
#                        random_state=42)

# %%
prediction = model.predict(x_test)
print(prediction.shape)
# Out:
# (418,)

# %%
importances = model.feature_importances_
importances

# %%
indices = np.argsort(importances)[::-1]
indices
#0번째 인덱스 중요도가 가장높다고 해석할 수 있다.

# %%
feature_names = ['Sex', 'Age', 'SibSp', 'Parch', 
       'Fare', 'Embarked_C', 'Embarked_S', 'Embarked_Q',
       'Pclass_1', 'Pclass_2', 'Pclass_3']

# %%
importance_names = [feature_names[i] for i in indices]
importance_names
#중요도 순으로 띄워짐

# %%
plt.fifgure()
plt.bar(range(len(importance_names)), importances[indices])
#importances 중요도 높은 순으로 정렬
plt.xticks(range(len(importance_names)), importances_names, rotation=90)
plt.show()

# %%
from sklearn.feature_selection import SelectionFromModel

# %%
model = RandomForestClassifier(max_depth=100,
                      max_features=0.8,
                      n_estimators=500,
                      random_state=42)

model

# %%
selector = SelectionFromModel(model, threshold=0.1)
seloctor 
#모델과 threath홀드?를 넣는다

# %%
feature_important = selector.fit_transform(train_df[feature_names], train_df['Survived'])
#중요한 핏쳐만 걸러냄

# %%
model.fit(feature_important, y_train)

# %%
proper_features = train_df[featrue_names].columns [selector.get_support()]
proper_features

# %%
prediction = model.predict(x_test[proper_features])
print(prediction.shape)

# %%
#[i for i in range(1,10])

# %%
from sklearn.metrics import mean_squared_error, accuracy_score

# %%
mean_squared_error(model.predict(x_train[proper_features]), y_train)
#모델과 y 오차 계산

# %%
accuracy_score(model.predict(x_train[proper_features]), y_train)
#train값을 맞춰야함
#정확도가 98%나온다. 크로스 밸리데이션 할때 20%돌리면 많이 낮아지니까 이걸 올리는게 목표

# %% [markdown]
# # Submit

# %%
submit = pd.read_csv('../Titanic_Disaster/DataSet/gender_submission.csv', index_col='PassengerId')
print(submit.shape)
submit.head()
# Out:
# (418, 1)
#              Survived
# PassengerId
# 892                 0
# 893                 1
# 894                 0
# 895                 0
# 896                 1

# %%
submit['Survived'] = prediction

# %%
submit.to_csv('submit.csv')

# %%
submit
# Out:
#              Survived
# PassengerId
# 892                 0
# 893                 0
# 894                 1
# 895                 1
# 896                 1
# ...               ...
# 1305                0
# 1306                1
# 1307                0
# 1308                0
# 1309                1
#
# [418 rows x 1 columns]
